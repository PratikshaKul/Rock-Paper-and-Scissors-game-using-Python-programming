# %% [markdown]
# ### Project:Rock, Paper and Scissors game using Python programming
# ### About the project: The project leverages the basic concepts of Python programming such as variables, data types, loop and conditional statements to develop the game of Rock, Papers and Scissors.
# ### Aim: Write a Python program to develop a Rock, Papers and Scissors game to be played against a computer.
# ### just to spice it up we are going to add two more elements - lizard and Spock
# ### the game rules looks like this:
# ![rules.png](attachment:rules.png)

# %%
### importing essential libraries
import random

### make a list for computer choice
Choice=['Rock','Paper','Sciessors','Lizard','Spock']

### here we are asking the users how many rounds he or she want to play
rounds=int(input("How many rounds you want to play: "))

### variables to count score in game  
computerwin,youwin=0,0

while True:
    print("Let's Start the Game: ")
    for i in range(1,rounds+1):
        print("round ",i)
        ### here we are taking the user choice as interger 
        userc=int(input("Please select between the choices: \n 1 for Rock \n 2 for Pepar \n 3 for Scissor \n 4 for Lizard \n 5 for spock \n"))
        ### converting user integer input to string 
        if userc==1:
            userc='Rock'
            print("you select ",userc)
        if userc==2:
            userc='Pepar'
            print("you select ",userc)
        if userc==3:
            userc='Scissor'
            print("you select ",userc)
        if userc==4:
            userc='Lizard'
            print("you select ",userc)
        if userc==5:
            userc='Spock'
            print("you select ",userc)
         ### taking computer input 
        computerc=random.choice(Choice)
        print('\ncomputer select',computerc)
        if(userc==computerc):
            print("it's a Draw")
        elif((userc=="Rock" and computerc=="Scissor") or (userc=="Rock" and computerc=="Lizard")):
            youwin=youwin+1
            print("You win this round")
            print("Score:\nYour score: ",youwin,"\nComputer score: ", computerwin)
        elif((userc=="Pepar" and computerc=="Rock") or (userc=="Pepar" and computerc=="Spock")):
            youwin=youwin+1
            print("You win this round")
            print("Score:\nYour score: ",youwin,"\nComputer score: ", computerwin)
        elif((userc=="Lizard" and computerc=="Pepar") or (userc=="Lizard" and computerc=="Spock")):
            youwin=youwin+1
            print("You win this round")
            print("Score:\nYour score: ",youwin,"\nComputer score: ", computerwin)
        elif((userc=="Spock" and computerc=="Rock") or (userc=="Spock" and computerc=="Scissor")):
            youwin=youwin+1
            print("You win this round")
            print("Score:\nYour score: ",youwin,"\nComputer score: ", computerwin)
        elif((userc=="Scissor" and computerc=="Pepar") or (userc=="Scissor" and computerc=="Rock")):
            youwin=youwin+1
            print("You win this round")
            print("Score:\nYour score: ",youwin,"\nComputer score: ", computerwin)
        else:
            computerwin=computerwin+1
            print("Computer win this round")
            print("Score:\nYour score: ",youwin,"\nComputer score: ", computerwin)
    if youwin>computerwin:
        print("you win this game:")
        print("Score:\nYour score: ",youwin,"\nComputer score: ", computerwin)
    elif youwin<computerwin:
        print("computer win this game:")
        print("Score:\nYour score: ",youwin,"\nComputer score: ", computerwin)
    else:
        print("this game is Draw")
        print("Score:\nYour score: ",youwin,"\nComputer score: ", computerwin)
    
    user_choise=input("Do you want to play again? press 1 to continue & any key to exit" )
    if(user_choise==1):
        continue
    else:
        break
